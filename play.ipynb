# %%
from bardogame import Bardogame

# %%
game = Bardogame("greg")

# %%
game.get_deck()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B192AD84E0>

# %%
game.card_table(4)
# Out:
# On the table:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB5E390>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB5E2E8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB5E0B8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB5E390>

# %%
game.draw_card(3)
# Out:
# Your hand:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB46DA0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB46D68>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB468D0>
# On the table:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB5E5F8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB46EB8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB5EF60>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB46E48>

# %%
game.show()
# Out:
# Your hand:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB5E4A8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB67048>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB675C0>
# On the table:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB676A0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB677F0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB677B8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB676A0>

# %%
game.play_card("1C")
# Out:
# Your hand:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1F828>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1F3C8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB1F518>
# On the table:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1FCF8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1FB38>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB1F588>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1F198>

# %%
game.win_card()

# %%
game.clear_hand()

# %%
game.clear_table()
