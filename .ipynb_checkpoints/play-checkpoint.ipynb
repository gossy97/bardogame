# %%
from bardogame import Bardogame

# %%
game = Bardogame("greg")

# %%
game.get_deck()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED1E77F0>

# %%
game.card_table(4)
# Out:
# On the table:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1A1ED38CEF0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1A1ED38CBE0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CB00>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CFD0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CF28>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CF60>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CBE0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CEF0>

# %%
game.draw_card(3)
# Out:
# Your hand:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38C828>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38C9B0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CA58>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CE80>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38CAC8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1A1ED38C828>
# On the table:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2f9094093a34> in <module>
# ----> 1 game.draw_card(3)
#
# ~\Desktop\bardogame\bardogame.py in draw_card(self, num_cards)
#      54         table = pd.read_sql("SELECT cards FROM TABLE", self.conn)
#      55         for i in range(len(table.CARDS)):
# ...

# %%
game.show()
# Out:
# Your hand:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB5E4A8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB67048>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB675C0>
# On the table:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB676A0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB677F0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB677B8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB676A0>

# %%
game.play_card("1C")
# Out:
# Your hand:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1F828>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1F3C8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB1F518>
# On the table:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1FCF8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1FB38>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=68x105 at 0x1B19BB1F588>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=69x105 at 0x1B19BB1F198>

# %%
game.win_card()

# %%
game.clear_hand()

# %%
game.clear_table()
